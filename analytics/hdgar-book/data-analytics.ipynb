# %% [markdown]
# # Data analytics

# %%
# !pip install google_auth_oauthlib 
# !pip install install google-api-python-client
# !pip install pandas 
# !pip install numpy
# !pip install matplotlib
# !pip install google-cloud-bigquery
# !pip install db-dtypes

# DEV GUIDES
#https://developers.google.com/analytics/devguides/reporting

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %load_ext autoreload
# %autoreload 2

import analytics_hca as hca

# %%
plot_dl_sessions, plot_dl_sessions_types, plot_dl_sessions_matrices = hca.plot_downloads()

# %% [markdown]
# ## File downloads - From download logs
#
# From Nov, 2021 to Mar, 2022 we were able to query download logs from the HCA DCP Google Cloud Platform (GCP). Here a session is counted as activity from a sinle IP address during a single day. This is likely an under esitmate of "downlaod sessions".  While downloads are logged for compliance reasons we no longer have access to the downlogs logs for analytics purposes.
#
# This represents downloads from all sources e.g. Terra workspaces, Azul API, Data Browser, notebooks etc.

# %%
plot_dl_sessions()

# %% [markdown]
# <div style="page-break-after: always"></div>

# %% [markdown]
# The following graphs break down the above downloads by file type category (FASTQ, BAM, matrix, or other). These categories are non-exclusive -- a single session may download files of multiple types.

# %%
plot_dl_sessions_types()

# %% [markdown]
# The matrix downloads are here broken down further, to show sessions downloading contributor-generated matrices, sessions downloading DCP matrices, and the overlap.

# %%
plot_dl_sessions_matrices()

# %%
plot_ethnicity_spec_unspec, plot_ethnicity_spec = hca.plot_ethnicity("dcp20")

# %% [markdown]
# <div style="page-break-after: always"></div>

# %% [markdown]
# ## Donor ethnicity
# Below we display the donor ethnicity metadata labels entered for donors up to the DCP20 release. (September, 2022)

# %%
plot_ethnicity_spec_unspec()

# %% [markdown]
# Of donors with recorded ethnicity fields, the number of occurrences of each ethnicity category is shown below.

# %%
plot_ethnicity_spec()

# %% [markdown]
# This chart shows the currently collected metadata as it would display in the Data Browser without additional wrangling to merge/consolidate categories.
