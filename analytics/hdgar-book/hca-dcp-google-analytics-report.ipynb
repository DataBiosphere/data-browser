# %% [markdown]
# # Analytics report

# %%
# !pip install google_auth_oauthlib 
# !pip install install google-api-python-client
# !pip install pandas 
# !pip install numpy
# !pip install matplotlib
# !pip install google-cloud-bigquery
# !pip install db-dtypes

# DEV GUIDES
#https://developers.google.com/analytics/devguides/reporting
# Out:
# Collecting google-cloud-bigquery
#   Using cached google_cloud_bigquery-3.0.1-py2.py3-none-any.whl (210 kB)
# Requirement already satisfied: packaging>=14.3 in d:\hunter_ext\anaconda3\lib\site-packages (from google-cloud-bigquery) (21.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in d:\hunter_ext\anaconda3\lib\site-packages (from google-cloud-bigquery) (2.26.0)
# Collecting google-resumable-media<3.0dev,>=0.6.0
#   Using cached google_resumable_media-2.3.2-py2.py3-none-any.whl (76 kB)
# Collecting grpcio<2.0dev,>=1.38.1
#   Downloading grpcio-1.44.0-cp39-cp39-win_amd64.whl (3.4 MB)
# Requirement already satisfied: protobuf>=3.12.0 in d:\hunter_ext\anaconda3\lib\site-packages (from google-cloud-bigquery) (3.19.4)
# Collecting proto-plus>=1.15.0
#   Using cached proto_plus-1.20.3-py3-none-any.whl (46 kB)
# Collecting google-cloud-bigquery-storage<3.0.0dev,>=2.0.0
#   Using cached google_cloud_bigquery_storage-2.13.0-py2.py3-none-any.whl (179 kB)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in d:\hunter_ext\anaconda3\lib\site-packages (from google-cloud-bigquery) (2.7.1)
# Collecting google-cloud-core<3.0.0dev,>=1.4.1
#   Using cached google_cloud_core-2.2.3-py2.py3-none-any.whl (29 kB)
# Collecting pyarrow<8.0dev,>=3.0.0
#   Downloading pyarrow-7.0.0-cp39-cp39-win_amd64.whl (16.1 MB)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in d:\hunter_ext\anaconda3\lib\site-packages (from google-cloud-bigquery) (2.8.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in d:\hunter_ext\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery) (1.56.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in d:\hunter_ext\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery) (2.6.2)
# Collecting grpcio-status<2.0dev,>=1.33.2
#   Using cached grpcio_status-1.45.0-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\hunter_ext\anaconda3\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\hunter_ext\anaconda3\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery) (4.8)
# Requirement already satisfied: six>=1.9.0 in d:\hunter_ext\anaconda3\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\hunter_ext\anaconda3\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery) (0.2.8)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.3.0-cp39-cp39-win_amd64.whl (27 kB)
# Collecting grpcio<2.0dev,>=1.38.1
#   Downloading grpcio-1.45.0-cp39-cp39-win_amd64.whl (3.5 MB)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\hunter_ext\anaconda3\lib\site-packages (from packaging>=14.3->google-cloud-bigquery) (3.0.4)
# Requirement already satisfied: numpy>=1.16.6 in d:\hunter_ext\anaconda3\lib\site-packages (from pyarrow<8.0dev,>=3.0.0->google-cloud-bigquery) (1.20.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\hunter_ext\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\hunter_ext\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-bigquery) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\hunter_ext\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-bigquery) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\hunter_ext\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-bigquery) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\hunter_ext\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-bigquery) (2021.10.8)
# Installing collected packages: grpcio, grpcio-status, proto-plus, google-crc32c, pyarrow, google-resumable-media, google-cloud-core, google-cloud-bigquery-storage, google-cloud-bigquery
# Successfully installed google-cloud-bigquery-3.0.1 google-cloud-bigquery-storage-2.13.0 google-cloud-core-2.2.3 google-crc32c-1.3.0 google-resumable-media-2.3.2 grpcio-1.45.0 grpcio-status-1.45.0 proto-plus-1.20.3 pyarrow-7.0.0
# WARNING: The candidate selected for download or install is a yanked version: 'grpcio' candidate (version 1.45.0 at https://files.pythonhosted.org/packages/69/c0/b35c8ddb5da51eae5eaa589ae3437742a3c7aafa1e67a23d5974d8f4c878/grpcio-1.45.0-cp39-cp39-win_amd64.whl#sha256=220867a53e53b2e201e98c55061e3053e31c0ce613625087242be684d3e8612a (from https://pypi.org/simple/grpcio/) (requires-python:>=3.6))
# Reason for being yanked: Segfaults
# Collecting db-dtypes
#   Using cached db_dtypes-1.0.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: pandas<2.0dev,>=0.24.2 in d:\hunter_ext\anaconda3\lib\site-packages (from db-dtypes) (1.3.4)
# Requirement already satisfied: packaging>=17.0 in d:\hunter_ext\anaconda3\lib\site-packages (from db-dtypes) (21.0)
# Requirement already satisfied: pyarrow<8.0dev,>=3.0.0 in d:\hunter_ext\anaconda3\lib\site-packages (from db-dtypes) (7.0.0)
# Requirement already satisfied: numpy<2.0dev,>=1.16.6 in d:\hunter_ext\anaconda3\lib\site-packages (from db-dtypes) (1.20.3)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\hunter_ext\anaconda3\lib\site-packages (from packaging>=17.0->db-dtypes) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\hunter_ext\anaconda3\lib\site-packages (from pandas<2.0dev,>=0.24.2->db-dtypes) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in d:\hunter_ext\anaconda3\lib\site-packages (from pandas<2.0dev,>=0.24.2->db-dtypes) (2021.3)
# Requirement already satisfied: six>=1.5 in d:\hunter_ext\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas<2.0dev,>=0.24.2->db-dtypes) (1.16.0)
# Installing collected packages: db-dtypes
# Successfully installed db-dtypes-1.0.0

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from IPython.display import display
import os
import pprint
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np
import analytics_api as ga

# %load_ext autoreload
# %autoreload 2

import analytics_charts as ac
GA_PROPERTY = "185740629" # HCA Data Portal/Browser
DCP_ANALYTICS_START = "2019-03-01"
TODAY = 'today'

ac.authenticate_ga()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=713613812354-ccedl8colb27q3q6rvvvjqrpb5tcbuug.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fanalytics.readonly&state=ihQq75EYLgPPCxw0CiQp02jk1ASN76&access_type=offline

# %%
ac.plot_users_over_time(GA_PROPERTY, DCP_ANALYTICS_START,TODAY)
# Out:
# <style type="text/css">
# #T_211a5_ th.col_heading {
#   text-align: center;
# }
# #T_211a5_ thead > tr:nth-child(2) {
#   display: none;
# }
# #T_211a5_ td.col1 {
#   text-align: left;
#   padding-left: 0;
# }
# #T_211a5_  td.col3 {
#   text-align: left;
#   padding-left: 0;
# }
# #T_211a5_row1_col1, #T_211a5_row1_col3, #T_211a5_row2_col1, #T_211a5_row2_col3, #T_211a5_row3_col1, #T_211a5_row3_col3, #T_211a5_row4_col1, #T_211a5_row4_col3, #T_211a5_row5_col1, #T_211a5_row5_col3, #T_211a5_row7_col1, #T_211a5_row8_col1, #T_211a5_row8_col3, #T_211a5_row9_col1, #T_211a5_row9_col3, #T_211a5_row12_col1, #T_211a5_row12_col3 {
#   color: green;
# }
# #T_211a5_row6_col1, #T_211a5_row6_col3, #T_211a5_row7_col3, #T_211a5_row10_col1, #T_211a5_row10_col3, #T_211a5_row11_col1, #T_211a5_row11_col3, #T_211a5_row13_col1, #T_211a5_row13_col3 {
#   color: red;
# }
# </style>
# <table id="T_211a5_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="2">Daily Users</th>
#       <th class="col_heading level0 col2" colspan="2">Unique Pageviews</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >Value</th>
#       <th class="col_heading level1 col1" >% Change</th>
#       <th class="col_heading level1 col2" >Value</th>
#       <th class="col_heading level1 col3" >% Change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Year</th>
#       <th class="index_name level1" >Quarter</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_211a5_level0_row0" class="row_heading level0 row0" rowspan="4">2019</th>
#       <th id="T_211a5_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_211a5_row0_col0" class="data row0 col0" >212</td>
#       <td id="T_211a5_row0_col1" class="data row0 col1" ></td>
#       <td id="T_211a5_row0_col2" class="data row0 col2" >1383</td>
#       <td id="T_211a5_row0_col3" class="data row0 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_211a5_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_211a5_row1_col0" class="data row1 col0" >1872</td>
#       <td id="T_211a5_row1_col1" class="data row1 col1" >(783.02%)</td>
#       <td id="T_211a5_row1_col2" class="data row1 col2" >11485</td>
#       <td id="T_211a5_row1_col3" class="data row1 col3" >(730.44%)</td>
#     </tr>
#     <tr>
#       <th id="T_211a5_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_211a5_row2_col0" class="data row2 col0" >3677</td>
#       <td id="T_211a5_row2_col1" class="data row2 col1" >(96.42%)</td>
#       <td id="T_211a5_row2_col2" class="data row2 col2" >24289</td>
#       <td id="T_211a5_row2_col3" class="data row2 col3" >(111.48%)</td>
#     </tr>
#     <tr>
#       <th id="T_211a5_level1_row3" class="row_heading level1 row3" >4</th>
#       <td id="T_211a5_row3_col0" class="data row3 col0" >5420</td>
#       <td id="T_211a5_row3_col1" class="data row3 col1" >(47.40%)</td>
#       <td id="T_211a5_row3_col2" class="data row3 col2" >34251</td>
#       <td id="T_211a5_row3_col3" class="data row3 col3" >(41.01%)</td>
#     </tr>
#     <tr>
#       <th id="T_211a5_level0_row4" class="row_heading level0 row4" rowspan="4">2020</th>
#       <th id="T_211a5_level1_row4" class="row_heading level1 row4" >1</th>
#       <td id="T_211a5_row4_col0" class="data row4 col0" >9889</td>
#       <td id="T_211a5_row4_col1" class="data row4 col1" >(82.45%)</td>
#       <td id="T_211a5_row4_col2" class="data row4 col2" >57200</td>
#       <td id="T_211a5_row4_col3" class="data row4 col3" >(67.00%)</td>
#     </tr>
#     <tr>
#       <th id="T_211a5_level1_row5" class="row_heading level1 row5" >2</th>
#       <td id="T_211a5_row5_col0" class="data row5 col0" >12609</td>
#       <td id="T_211a5_row5_col1" class="data row5 col1" >(27.51%)</td>
#       <td id="T_211a5_row5_col2" class="data row5 col2" >65887</td>
#       <td id="T_211a5_row5_col3" class="data row5 col3" >(15.19%)</td>
#     </tr>
#     <tr>
#       <th id="T_211a5_level1_row6" class="row_heading level1 row6" >3</th>
#       <td id="T_211a5_row6_col0" class="data row6 col0" >10510</td>
#       <td id="T_211a5_row6_col1" class="data row6 col1" >(-16.65%)</td>
#       <td id="T_211a5_row6_col2" class="data row6 col2" >53574</td>
#       <td id="T_211a5_row6_col3" class="data row6 col3" >(-18.69%)</td>
#     </tr>
#     <tr>
#       <th id="T_211a5_level1_row7" class="row_heading level1 row7" >4</th>
#       <td id="T_211a5_row7_col0" class="data row7 col0" >11189</td>
#       <td id="T_211a5_row7_col1" class="data row7 col1" >(6.46%)</td>
#       <td id="T_211a5_row7_col2" class="data row7 col2" >50930</td>
#       <td id="T_211a5_row7_col3" class="data row7 col3" >(-4.94%)</td>
#     </tr>
#     <tr>
#       <th id="T_211a5_level0_row8" class="row_heading level0 row8" rowspan="4">2021</th>
#       <th id="T_211a5_level1_row8" class="row_heading level1 row8" >1</th>
#       <td id="T_211a5_row8_col0" class="data row8 col0" >12480</td>
#       <td id="T_211a5_row8_col1" class="data row8 col1" >(11.54%)</td>
#       <td id="T_211a5_row8_col2" class="data row8 col2" >59957</td>
#       <td id="T_211a5_row8_col3" class="data row8 col3" >(17.72%)</td>
#     </tr>
#     <tr>
#       <th id="T_211a5_level1_row9" class="row_heading level1 row9" >2</th>
#       <td id="T_211a5_row9_col0" class="data row9 col0" >14226</td>
#       <td id="T_211a5_row9_col1" class="data row9 col1" >(13.99%)</td>
#       <td id="T_211a5_row9_col2" class="data row9 col2" >68920</td>
#       <td id="T_211a5_row9_col3" class="data row9 col3" >(14.95%)</td>
#     </tr>
#     <tr>
#       <th id="T_211a5_level1_row10" class="row_heading level1 row10" >3</th>
#       <td id="T_211a5_row10_col0" class="data row10 col0" >11926</td>
#       <td id="T_211a5_row10_col1" class="data row10 col1" >(-16.17%)</td>
#       <td id="T_211a5_row10_col2" class="data row10 col2" >60388</td>
#       <td id="T_211a5_row10_col3" class="data row10 col3" >(-12.38%)</td>
#     </tr>
#     <tr>
#       <th id="T_211a5_level1_row11" class="row_heading level1 row11" >4</th>
#       <td id="T_211a5_row11_col0" class="data row11 col0" >11923</td>
#       <td id="T_211a5_row11_col1" class="data row11 col1" >(-0.03%)</td>
#       <td id="T_211a5_row11_col2" class="data row11 col2" >59237</td>
#       <td id="T_211a5_row11_col3" class="data row11 col3" >(-1.91%)</td>
#     </tr>
#     <tr>
#       <th id="T_211a5_level0_row12" class="row_heading level0 row12" rowspan="2">2022</th>
#       <th id="T_211a5_level1_row12" class="row_heading level1 row12" >1</th>
#       <td id="T_211a5_row12_col0" class="data row12 col0" >13690</td>
#       <td id="T_211a5_row12_col1" class="data row12 col1" >(14.82%)</td>
#       <td id="T_211a5_row12_col2" class="data row12 col2" >71142</td>
#       <td id="T_211a5_row12_col3" class="data row12 col3" >(20.10%)</td>
#     </tr>
#     <tr>
#       <th id="T_211a5_level1_row13" class="row_heading level1 row13" >2</th>
#       <td id="T_211a5_row13_col0" class="data row13 col0" >792</td>
#       <td id="T_211a5_row13_col1" class="data row13 col1" >(-94.21%)</td>
#       <td id="T_211a5_row13_col2" class="data row13 col2" >3734</td>
#       <td id="T_211a5_row13_col3" class="data row13 col3" >(-94.75%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
ac.plot_hbar(GA_PROPERTY,"Top Referrers, Last 90 Days", "Users", "Referrer", "ga:users","ga:source", '90daysAgo',"today")
ac.plot_hbar(GA_PROPERTY, "Top Countries, Last 90 Days", "Users", "Country", "ga:users","ga:country", '90daysAgo',"today")
ac.plot_hbar(GA_PROPERTY, "Entrances", "Entrances", "Page", "ga:entrances","ga:pagePath", '90daysAgo',"today")

# %%
ac.show_difference_table(GA_PROPERTY, "Entrances", "Page", "ga:entrances","ga:pagePath", "2022Q1", "2021Q4")
# Out:
# <style type="text/css">
# #T_9c46f_ th.col_heading {
#   text-align: center;
# }
# #T_9c46f_ thead > tr:nth-child(2) {
#   display: none;
# }
# #T_9c46f_ td.col1 {
#   text-align: left;
#   padding-left: 0;
# }
# #T_9c46f_row0_col1, #T_9c46f_row1_col1, #T_9c46f_row2_col1, #T_9c46f_row3_col1, #T_9c46f_row4_col1, #T_9c46f_row5_col1, #T_9c46f_row7_col1, #T_9c46f_row8_col1, #T_9c46f_row12_col1, #T_9c46f_row16_col1, #T_9c46f_row17_col1, #T_9c46f_row18_col1, #T_9c46f_row19_col1 {
#   color: red;
# }
# #T_9c46f_row6_col1, #T_9c46f_row9_col1, #T_9c46f_row10_col1, #T_9c46f_row11_col1, #T_9c46f_row13_col1, #T_9c46f_row14_col1, #T_9c46f_row15_col1 {
#   color: green;
# }
# </style>
# <table id="T_9c46f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="2">Entrances</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >Value</th>
#       <th class="col_heading level1 col1" >% Change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Page</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c46f_level0_row0" class="row_heading level0 row0" >/</th>
#       <td id="T_9c46f_row0_col0" class="data row0 col0" >5764</td>
#       <td id="T_9c46f_row0_col1" class="data row0 col1" >(-10.22%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row1" class="row_heading level0 row1" >/analyze/portals/single-cell-expression-atlas</th>
#       <td id="T_9c46f_row1_col0" class="data row1 col0" >1056</td>
#       <td id="T_9c46f_row1_col1" class="data row1 col1" >(-17.90%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row2" class="row_heading level0 row2" >/explore/projects</th>
#       <td id="T_9c46f_row2_col0" class="data row2 col0" >674</td>
#       <td id="T_9c46f_row2_col1" class="data row2 col1" >(-5.64%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row3" class="row_heading level0 row3" >/explore/projects/cc95ff89-2e68-4a08-a234-480eca21ce79</th>
#       <td id="T_9c46f_row3_col0" class="data row3 col0" >556</td>
#       <td id="T_9c46f_row3_col1" class="data row3 col1" >(-11.51%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row4" class="row_heading level0 row4" >/analyze/portals/cellxgene</th>
#       <td id="T_9c46f_row4_col0" class="data row4 col0" >354</td>
#       <td id="T_9c46f_row4_col1" class="data row4 col1" >(-27.40%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row5" class="row_heading level0 row5" >/analyze/methods/infer</th>
#       <td id="T_9c46f_row5_col0" class="data row5 col0" >339</td>
#       <td id="T_9c46f_row5_col1" class="data row5 col1" >(-4.42%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row6" class="row_heading level0 row6" >/pipelines/smart-seq2-workflow</th>
#       <td id="T_9c46f_row6_col0" class="data row6 col0" >321</td>
#       <td id="T_9c46f_row6_col1" class="data row6 col1" >(+4.05%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row7" class="row_heading level0 row7" >/explore/projects?filter=[{"facetName":"organ","terms":["immune system"]}]&catalog=dcp1</th>
#       <td id="T_9c46f_row7_col0" class="data row7 col0" >210</td>
#       <td id="T_9c46f_row7_col1" class="data row7 col1" >(-14.29%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row8" class="row_heading level0 row8" >/explore/projects/4d6f6c96-2a83-43d8-8fe1-0f53bffd4674</th>
#       <td id="T_9c46f_row8_col0" class="data row8 col0" >161</td>
#       <td id="T_9c46f_row8_col1" class="data row8 col1" >(-3.73%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row9" class="row_heading level0 row9" >/explore/projects/abe1a013-af7a-45ed-8c26-f3793c24a1f4</th>
#       <td id="T_9c46f_row9_col0" class="data row9 col0" >137</td>
#       <td id="T_9c46f_row9_col1" class="data row9 col1" >(+0.73%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row10" class="row_heading level0 row10" >/analyze</th>
#       <td id="T_9c46f_row10_col0" class="data row10 col0" >125</td>
#       <td id="T_9c46f_row10_col1" class="data row10 col1" >(+37.60%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row11" class="row_heading level0 row11" >/analyze/portals/single-cell-portal</th>
#       <td id="T_9c46f_row11_col0" class="data row11 col0" >124</td>
#       <td id="T_9c46f_row11_col1" class="data row11 col1" >(+19.35%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row12" class="row_heading level0 row12" >/explore/projects/c4077b3c-5c98-4d26-a614-246d12c2e5d7</th>
#       <td id="T_9c46f_row12_col0" class="data row12 col0" >110</td>
#       <td id="T_9c46f_row12_col1" class="data row12 col1" >(-27.27%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row13" class="row_heading level0 row13" >/explore/projects/091cf39b-01bc-42e5-9437-f419a66c8a45</th>
#       <td id="T_9c46f_row13_col0" class="data row13 col0" >100</td>
#       <td id="T_9c46f_row13_col1" class="data row13 col1" >(+29.00%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row14" class="row_heading level0 row14" >/analyze/portals/asap</th>
#       <td id="T_9c46f_row14_col0" class="data row14 col0" >95</td>
#       <td id="T_9c46f_row14_col1" class="data row14 col1" >(+27.37%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row15" class="row_heading level0 row15" >/metadata</th>
#       <td id="T_9c46f_row15_col0" class="data row15 col0" >91</td>
#       <td id="T_9c46f_row15_col1" class="data row15 col1" >(+38.46%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row16" class="row_heading level0 row16" >/explore/projects?filter=[{"facetName":"specimenOrgan","terms":["blood"]}]</th>
#       <td id="T_9c46f_row16_col0" class="data row16 col0" >91</td>
#       <td id="T_9c46f_row16_col1" class="data row16 col1" >(-27.47%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row17" class="row_heading level0 row17" >/pipelines/optimus-workflow</th>
#       <td id="T_9c46f_row17_col0" class="data row17 col0" >90</td>
#       <td id="T_9c46f_row17_col1" class="data row17 col1" >(-14.44%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row18" class="row_heading level0 row18" >/explore/projects/c1810dbc-16d2-45c3-b45e-3e675f88d87b</th>
#       <td id="T_9c46f_row18_col0" class="data row18 col0" >88</td>
#       <td id="T_9c46f_row18_col1" class="data row18 col1" >(-32.95%)</td>
#     </tr>
#     <tr>
#       <th id="T_9c46f_level0_row19" class="row_heading level0 row19" >/explore/projects/4a95101c-9ffc-4f30-a809-f04518a23803</th>
#       <td id="T_9c46f_row19_col0" class="data row19 col0" >85</td>
#       <td id="T_9c46f_row19_col1" class="data row19 col1" >(-40.00%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
ac.plot_downloads()

# %%
ac.plot_ethnicity()
